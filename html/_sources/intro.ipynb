# %% [markdown]
# # Cahier d'apprentissage

# %% [markdown]
# ## Par Aude Pertron de la promo Kusanagi
#
# <img src="https://64.media.tumblr.com/75619a5247246975b51b9f6700615b72/tumblr_n7dceunFcu1teiu7jo1_1280.png" alt="Logo promo" style="width: 500px;"/>

# %% [markdown]
# ## Introduction
# Mes objectifs d'apprenante avec ce cahier sont de retrouver facilement mes notes sur des sujets interessants, dont je pourrais avoir à nouveau besoin à l'avenir.

# %% [markdown]
# <img src="images/pandas.png">

# %% [markdown]
#     from IPython.display import IFrame, display
#     filepath = "images/sql_katas.pdf"
#     IFrame(filepath, width=700, height=400)

# %% [markdown]
# <p style=color:orange>test</p>
